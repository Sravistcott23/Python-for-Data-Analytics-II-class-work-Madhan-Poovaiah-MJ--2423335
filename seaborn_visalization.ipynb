# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/madhanmj/python for data analytics 2'

# %%
piece=pd.read_csv('/Users/madhanmj/Downloads/Piece_Dim - Piece_Dim.csv')
piece.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
piece.describe()
# Out:
#            Length      Width     Height
# count   50.000000  50.000000  50.000000
# mean   100.128800  49.461400  20.014000
# std      5.075593   2.615639   1.074069
# min     89.820000  44.460000  17.370000
# 25%     95.675000  48.105000  19.375000
# 50%     99.830000  49.315000  19.930000
# 75%    104.402500  50.780000  20.595000
# max    110.540000  55.760000  23.110000

# %%
plt.hist(piece['Length'])
plt.show()

# %%
plt.hist(piece['Length'],bins=15,color='red')
plt.show()

# %%
plt.hist(piece['Length'],bins=15,color='red')
plt.xlabel('Length in MM')
plt.ylabel('Count')
plt.title('Histogram of piece in lenght')
plt.show()

# %%
plt.hist(piece['Length'])
plt.show()

# %%
sns.displot(data=piece,x='Length')
plt.show()

# %%
sns.displot(data=piece,x='Length')
plt.title('Histogram')
plt.show()

# %%
sns.displot(data=piece,x='Length',hue='Operator')
plt.title('Histogram')
plt.show()

# %%
sns.displot(data=piece,x='Length',col='Operator')
plt.show()

# %%
sns.displot(data=piece,x='Length',col='Operator',kind='kde')
plt.show()

# %%
sns.displot(data=piece,x='Length',rug=True,kind='kde')
plt.show()

# %%
sns.displot(data=piece,x='Length',rug=True,kind='kde',hue='Operator')
plt.show()

# %%
        sns.displot(data=piece,x='Length',rug=True,kind='ecdf')

# %%
sns.displot(data=piece,x='Length',rug=True,kde=True)

# %%
sns.displot(data=piece,x='Length',y='Width')

# %%
sns.displot(data=piece,x='Length',y='Width',kind='kde')

# %%
sns.catplot(data=piece,x='Operator',y='Length')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='swarm')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='box')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='violin')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='boxen')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='point')

# %%
sns.catplot(data=piece,x='Operator',y='Length',kind='bar')

# %%
sns.catplot(data=piece,x='Operator',kind='count')

# %%
sns.relplot(data=piece,x='Length',y='Width')

# %%
sns.relplot(data=piece,x='Length',y='Width',hue='Operator')

# %%
sns.relplot(data=piece,x='Length',y='Width',col='Operator')

# %%
sns.relplot(data=piece,x='Length',y='Width',row='Operator')

# %%
sns.relplot(data=piece,x='Item_No',y='Length',kind='line',aspect=3)

# %%
sns.relplot(data=piece,x='Item_No',y='Length',kind='line',aspect=3)
#plt.xticks(rotation=45)
plt.xticks(rotation=45)
plt.show()

# %%
sns.regplot(data=piece,x='Length',y='Width')
# Out:
# <Axes: xlabel='Length', ylabel='Width'>

# %%
# Calculate correlation matrix
correlation_cols = ['Length', 'Width', 'Height']
corr_matrix = piece[correlation_cols].corr()

# %%
correlation_cols = ['Length', 'Width', 'Height']

# %%
corr_matrix = piece[correlation_cols].corr()

# %%
piece.columns
# Out:
# Index(['Item_No', 'Length', 'Width', 'Height', 'Operator'], dtype='object')

# %%
print("\nCorrelation Matrix:")
print(corr_matrix.round(2).to_string())
# Out:
# Correlation Matrix:
#         Length  Width  Height
# Length    1.00   0.05    0.01
# Width     0.05   1.00   -0.02
# Height    0.01  -0.02    1.00

# %%
# Create correlation heatmap
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='RdYlBu_r', center=0, 
            fmt='.2f', square=True, linewidths=0.5,
            annot_kws={'size': 10})
plt.title('Piece_Dim', fontsize=14, fontweight='bold')
plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(3, 2))
sns.heatmap(corr_matrix, annot=True, cmap='RdYlBu_r', center=1, 
            fmt='.2f', square=True, linewidths=0.5,
            annot_kws={'size': 9})
plt.title('Piece_Dim', fontsize=8, fontweight='bold')
plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(3, 2))
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
# Create a pair plot
sns.pairplot(piece);

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.displot(data=iris,x='sepal_length',hue='sepal_width')

# %%
sns.displot(data=titanic,x='age',col='sex')

# %%
sns.displot(data=titanic,x='age',col='sex',hue='survived')

# %%
sns.displot(data=titanic,x='age',col='sex',row='survived')

# %%
sns.displot(data=titanic,x='age',col='sex',kind='kde',row='survived')

# %%
sns.catplot(data=titanic,x='survived',y='age')

# %%
sns.catplot(data=titanic,x='survived',y='age',kind='swarm',aspect=1.5)

# %%
sns.catplot(data=titanic,x='survived',y='age',kind='violin',aspect=1.5)

# %%
sns.catplot(data=titanic,x='survived',y='age',kind='box',aspect=1.5)

# %%
sns.catplot(data=titanic,x='survived',y='age',kind='boxen',aspect=1.5)

# %%
sns.catplot(data=titanic,x='sex',kind='count')

# %%
sns.catplot(data=titanic,x='sex',kind='count',hue='survived')

# %%
sns.catplot(data=titanic,x='deck',kind='count',hue='survived')
