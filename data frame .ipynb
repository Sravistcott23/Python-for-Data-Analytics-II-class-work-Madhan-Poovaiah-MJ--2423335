# %%
import pandas as pd 
import numpy as np

# %%
data={"Region":["Asia","Asia","Europe","Europe","America","America"],
      "country":["China","india","France","Germany","America","Canada"],
      "Year":[2025,2023,2024,2022,2021,2025],
      "Sales":[2000,30000,40000,50000,10000,70000],
      "Profit":[300,400,500,600,700,800]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Region  country  Year  Sales  Profit
# 0     Asia    China  2025   2000     300
# 1     Asia    india  2023  30000     400
# 2   Europe   France  2024  40000     500
# 3   Europe  Germany  2022  50000     600
# 4  America  America  2021  10000     700
# 5  America   Canada  2025  70000     800

# %%
df.grouby(["Region"])[["Sales","Profit"]].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.grouby(["Region"])[["Sales","Profit"]].mean()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
import numpy as np

# %%
data={"Region":["Asia","Asia","Europe","Europe","America","America"],
      "country":["China","india","France","Germany","America","Canada"],
      "Year":[2025,2023,2024,2022,2021,2025],
      "Sales":[2000,30000,40000,50000,10000,70000],
      "Profit":[300,400,500,600,700,800]}

# %%
df=pd.D
