# %%
import pandas as pd 
import numpy as np

# %%
# making series with list and series is 2 diamentional

# %%
ice_cream=["Strawberry","Chocolate","Vanilla","Tuttyfruity"]

# %%
ice_cream
# Out:
# ['Strawberry', 'Chocolate', 'Vanilla', 'Tuttyfruity']

# %%
pd.Series(ice_cream)
# Out:
# 0     Strawberry
# 1      Chocolate
# 2        Vanilla
# 3    Tuttyfruity
# dtype: object

# %%
age=[23,19,18,20,22,30]
age
# Out:
# [23, 19, 18, 20, 22, 30]

# %%
pd.Series(age)
# Out:
# 0    23
# 1    19
# 2    18
# 3    20
# 4    22
# 5    30
# dtype: int64

# %%
price=[1.2,2.3,3.2,6.8]
pd.Series(price)
# Out:
# 0    1.2
# 1    2.3
# 2    3.2
# 3    6.8
# dtype: float64

# %%
# making series using dicationary

# %%
sushi={"Tunna":"Red","Salmon":"Orange","Eel":"Brown"}
pd.Series(sushi)
# Out:
# Tunna        Red
# Salmon    Orange
# Eel        Brown
# dtype: object

# %%
# Methods and atributues

# %%
#making series using method

# %%
price_1=pd.Series([23.5,45,78,2,5])

# %%
price_1
# Out:
# 0    23.5
# 1    45.0
# 2    78.0
# 3     2.0
# 4     5.0
# dtype: float64

# %%
price_1.sum()
# Out:
# 153.5

# %%
price_1.mean()
# Out:
# 30.7

# %%
price_1.std()
# Out:
# 31.53490129998824

# %%
#attributes

# %%
adjectives=pd.Series(["Beautiful","Smart","Intelligent","Handsome","Smart"])
adjectives
# Out:
# 0      Beautiful
# 1          Smart
# 2    Intelligent
# 3       Handsome
# 4          Smart
# dtype: object

# %%
adjectives.size # in attributes you dont put () at the end
# Out:
# 5

# %%
adjectives.values # it shows all the different attributes
# Out:
# array(['Beautiful', 'Smart', 'Intelligent', 'Handsome', 'Smart'],
#       dtype=object)

# %%
adjectives.is_unique #because we have 2 repated values
# Out:
# False

# %%
type(adjectives.values)
# Out:
# numpy.ndarray

# %%
weekdays=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
Fruits=["Apple","Banana","Orange","Gauva","Lichhi","Kiwi","Mango"]

# %%
pd.Series(weekdays,Fruits)
# Out:
# Apple        Monday
# Banana      Tuesday
# Orange    Wednesday
# Gauva      Thursday
# Lichhi       Friday
# Kiwi       Saturday
# Mango        Sunday
# dtype: object

# %%
pd.Series(Fruits,weekdays)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Orange
# Thursday      Gauva
# Friday       Lichhi
# Saturday       Kiwi
# Sunday        Mango
# dtype: object

# %%
pd.Series(index=weekdays,data=Fruits)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Orange
# Thursday      Gauva
# Friday       Lichhi
# Saturday       Kiwi
# Sunday        Mango
# dtype: object
